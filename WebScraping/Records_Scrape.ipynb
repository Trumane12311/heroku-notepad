# %%
#Import Dependencies 
import pandas as pd
import geopandas as gp

# %% [markdown]
# ## Speed Record Holders Scrape & GeoJSON Creation

# %%
#Set URL for Speed Record Scrape
speed_record_url = 'https://rcdb.com/rhr.htm?m=0'

speed_tables = pd.read_html(speed_record_url)

# %%
#Scrape Speed Record Table and save as a dataframe.
speed_record = speed_tables[1]
speed_record
# Out:
#     Rank      Speed                                     Roller Coaster  \
# 0    1st  149.1 mph                                      Formula Rossa
# 1    2nd    128 mph                                          Kingda Ka
# 2    3rd    120 mph                                Top Thrill Dragster
# 3    4th  111.8 mph                                Do-DodonpaRed Force
# 4    5th    100 mph                      Superman: Escape from Krypton
# 5      *   99.4 mph                                         Ring Racer
# 6    6th     95 mph                          Steel Dragon 2000Fury 325
# 7    7th     93 mph                                   Millennium Force
# 8    8th     92 mph                                          Leviathan
# 9    9th     91 mph                                              Orion
# 10  10th     90 mph                                    Intimidator 305
# 11     *          *  Rankings are not assigned to roller coasters t...
#
# ...

# %%
#Drop unwanted Rows
speed_record = speed_record.drop(labels=[5,11], axis=0)

#Drop unwanted Column
speed_record = speed_record.drop(labels="Opened", axis=1)

speed_record
# Out:
#     Rank      Speed                 Roller Coaster  \
# 0    1st  149.1 mph                  Formula Rossa
# 1    2nd    128 mph                      Kingda Ka
# 2    3rd    120 mph            Top Thrill Dragster
# 3    4th  111.8 mph            Do-DodonpaRed Force
# 4    5th    100 mph  Superman: Escape from Krypton
# 6    6th     95 mph      Steel Dragon 2000Fury 325
# 7    7th     93 mph               Millennium Force
# 8    8th     92 mph                      Leviathan
# 9    9th     91 mph                          Orion
# 10  10th     90 mph                Intimidator 305
#
#                             Amusement Park (Location)
# 0   Ferrari World Abu Dhabi (Abu Dhabi, Abu Dhabi,...
# 1   Six Flags Great Adventure (Jackson, New Jersey...
# 2         Cedar Point (Sandusky, Ohio, United States)
# 3   Fuji-Q Highland (Fujiyoshida, Yamanashi, Japan...
# 4   Six Flags Magic Mountain (Valencia, California...
# 6   Nagashima Spa Land (Kuwana, Mie, Japan)Carowin...
# ...

# %%
#Fix Data with Tied Record Holders
speed_fixes = [pd.Series(['4th', '111.8 mph', 'Do-Dodonpa', 'Fuji-Q Highland (Fujiyoshida, Yamanashi, Japan)'], index=speed_record.columns),
                pd.Series(['4th', '111.8 mph', 'Red Force', 'Ferrari Land (Salou, Tarragona, Catalonia, Spain)'], index=speed_record.columns),
                pd.Series(['6th', '95 mph', 'Steel Dragon 2000', 'Nagashima Spa Land (Kuwana, Mie, Japan)'], index=speed_record.columns),
                pd.Series(['6th', '95 mph', 'Fury 325', 'Carowinds (Charlotte, North Carolina, United States)'], index=speed_record.columns)]
speed_records_fixed = speed_record.append(speed_fixes,ignore_index=True)
speed_records_fixed

#Drop Rows with dirty data
speed_records_clean = speed_records_fixed.drop(labels=[3,5], axis=0)
speed_records_clean
# Out:
#     Rank      Speed                 Roller Coaster  \
# 0    1st  149.1 mph                  Formula Rossa
# 1    2nd    128 mph                      Kingda Ka
# 2    3rd    120 mph            Top Thrill Dragster
# 4    5th    100 mph  Superman: Escape from Krypton
# 6    7th     93 mph               Millennium Force
# 7    8th     92 mph                      Leviathan
# 8    9th     91 mph                          Orion
# 9   10th     90 mph                Intimidator 305
# 10   4th  111.8 mph                     Do-Dodonpa
# 11   4th  111.8 mph                      Red Force
# 12   6th     95 mph              Steel Dragon 2000
# 13   6th     95 mph                       Fury 325
#
#                             Amusement Park (Location)
# 0   Ferrari World Abu Dhabi (Abu Dhabi, Abu Dhabi,...
# 1   Six Flags Great Adventure (Jackson, New Jersey...
# 2         Cedar Point (Sandusky, Ohio, United States)
# 4   Six Flags Magic Mountain (Valencia, California...
# ...

# %%
#Split the Amusement Park (Location) column & then Drop It
speed_records_clean[['Amusement Park','Location']] = speed_records_clean['Amusement Park (Location)'].str.split('(',expand=True)
speed_records_clean = speed_records_clean.drop(labels=['Amusement Park (Location)'], axis=1)
speed_records_clean
# Out:
#     Rank      Speed                 Roller Coaster  \
# 0    1st  149.1 mph                  Formula Rossa
# 1    2nd    128 mph                      Kingda Ka
# 2    3rd    120 mph            Top Thrill Dragster
# 4    5th    100 mph  Superman: Escape from Krypton
# 6    7th     93 mph               Millennium Force
# 7    8th     92 mph                      Leviathan
# 8    9th     91 mph                          Orion
# 9   10th     90 mph                Intimidator 305
# 10   4th  111.8 mph                     Do-Dodonpa
# 11   4th  111.8 mph                      Red Force
# 12   6th     95 mph              Steel Dragon 2000
# 13   6th     95 mph                       Fury 325
#
#                 Amusement Park                                     Location
# 0     Ferrari World Abu Dhabi   Abu Dhabi, Abu Dhabi, United Arab Emirates)
# 1   Six Flags Great Adventure           Jackson, New Jersey, United States)
# ...

# %%
#Split the Location into City, State, Country, Etc. 
speed_records_clean[['City', 'State', 'Country1', 'Extra']] = speed_records_clean['Location'].str.split(',', expand=True)
speed_records_clean
# Out:
#     Rank      Speed                 Roller Coaster  \
# 0    1st  149.1 mph                  Formula Rossa
# 1    2nd    128 mph                      Kingda Ka
# 2    3rd    120 mph            Top Thrill Dragster
# 4    5th    100 mph  Superman: Escape from Krypton
# 6    7th     93 mph               Millennium Force
# 7    8th     92 mph                      Leviathan
# 8    9th     91 mph                          Orion
# 9   10th     90 mph                Intimidator 305
# 10   4th  111.8 mph                     Do-Dodonpa
# 11   4th  111.8 mph                      Red Force
# 12   6th     95 mph              Steel Dragon 2000
# 13   6th     95 mph                       Fury 325
#
#                 Amusement Park                                     Location  \
# 0     Ferrari World Abu Dhabi   Abu Dhabi, Abu Dhabi, United Arab Emirates)
# 1   Six Flags Great Adventure           Jackson, New Jersey, United States)
# ...

# %%
#Dop Location Column
speed_records_clean = speed_records_clean.drop(labels=['Location'], axis=1)
speed_records_clean
# Out:
#     Rank      Speed                 Roller Coaster  \
# 0    1st  149.1 mph                  Formula Rossa
# 1    2nd    128 mph                      Kingda Ka
# 2    3rd    120 mph            Top Thrill Dragster
# 4    5th    100 mph  Superman: Escape from Krypton
# 6    7th     93 mph               Millennium Force
# 7    8th     92 mph                      Leviathan
# 8    9th     91 mph                          Orion
# 9   10th     90 mph                Intimidator 305
# 10   4th  111.8 mph                     Do-Dodonpa
# 11   4th  111.8 mph                      Red Force
# 12   6th     95 mph              Steel Dragon 2000
# 13   6th     95 mph                       Fury 325
#
#                 Amusement Park         City            State  \
# 0     Ferrari World Abu Dhabi     Abu Dhabi        Abu Dhabi
# 1   Six Flags Great Adventure       Jackson       New Jersey
# 2                 Cedar Point      Sandusky             Ohio
# ...

# %%
#Remove ) from Country 1
speed_records_clean['Country1'] = speed_records_clean['Country1'].str[:-1]
speed_records_clean
# Out:
#     Rank      Speed                 Roller Coaster  \
# 0    1st  149.1 mph                  Formula Rossa
# 1    2nd    128 mph                      Kingda Ka
# 2    3rd    120 mph            Top Thrill Dragster
# 4    5th    100 mph  Superman: Escape from Krypton
# 6    7th     93 mph               Millennium Force
# 7    8th     92 mph                      Leviathan
# 8    9th     91 mph                          Orion
# 9   10th     90 mph                Intimidator 305
# 10   4th  111.8 mph                     Do-Dodonpa
# 11   4th  111.8 mph                      Red Force
# 12   6th     95 mph              Steel Dragon 2000
# 13   6th     95 mph                       Fury 325
#
#                 Amusement Park         City            State  \
# 0     Ferrari World Abu Dhabi     Abu Dhabi        Abu Dhabi
# 1   Six Flags Great Adventure       Jackson       New Jersey
# 2                 Cedar Point      Sandusky             Ohio
# ...

# %%
#Fix Country1 Column Data
speed_records_clean["Country1"] = speed_records_clean["Country1"].str.replace("Cataloni","Spain")
speed_records_clean
# Out:
#     Rank      Speed                 Roller Coaster  \
# 0    1st  149.1 mph                  Formula Rossa
# 1    2nd    128 mph                      Kingda Ka
# 2    3rd    120 mph            Top Thrill Dragster
# 4    5th    100 mph  Superman: Escape from Krypton
# 6    7th     93 mph               Millennium Force
# 7    8th     92 mph                      Leviathan
# 8    9th     91 mph                          Orion
# 9   10th     90 mph                Intimidator 305
# 10   4th  111.8 mph                     Do-Dodonpa
# 11   4th  111.8 mph                      Red Force
# 12   6th     95 mph              Steel Dragon 2000
# 13   6th     95 mph                       Fury 325
#
#                 Amusement Park         City            State  \
# 0     Ferrari World Abu Dhabi     Abu Dhabi        Abu Dhabi
# 1   Six Flags Great Adventure       Jackson       New Jersey
# 2                 Cedar Point      Sandusky             Ohio
# ...

# %%
#Drop Extra Column and create Final Dataframe
speed_records_final = speed_records_clean.drop(labels=['Extra'], axis=1)
speed_records_final = speed_records_final.rename(columns={'Country1': 'Country'})
speed_records_final
# Out:
#     Rank      Speed                 Roller Coaster  \
# 0    1st  149.1 mph                  Formula Rossa
# 1    2nd    128 mph                      Kingda Ka
# 2    3rd    120 mph            Top Thrill Dragster
# 4    5th    100 mph  Superman: Escape from Krypton
# 6    7th     93 mph               Millennium Force
# 7    8th     92 mph                      Leviathan
# 8    9th     91 mph                          Orion
# 9   10th     90 mph                Intimidator 305
# 10   4th  111.8 mph                     Do-Dodonpa
# 11   4th  111.8 mph                      Red Force
# 12   6th     95 mph              Steel Dragon 2000
# 13   6th     95 mph                       Fury 325
#
#                 Amusement Park         City            State  \
# 0     Ferrari World Abu Dhabi     Abu Dhabi        Abu Dhabi
# 1   Six Flags Great Adventure       Jackson       New Jersey
# 2                 Cedar Point      Sandusky             Ohio
# ...

# %%
#Read in the Speed_Cities GeoJSON
speed_cities = gp.read_file('geojsons/speed_cities.geojson')
speed_cities
# Out:
#            City                     geometry
# 0     Abu Dhabi    POINT (54.37408 24.47715)
# 1       Jackson   POINT (-74.42928 40.13295)
# 2      Sandusky   POINT (-82.70645 41.45019)
# 3   Fujiyoshida   POINT (138.83337 35.48122)
# 4         Salou     POINT (1.14378 41.07702)
# 5      Valencia  POINT (-118.56128 34.41396)
# 6        Kuwana   POINT (136.64967 35.04827)
# 7     Charlotte   POINT (-80.84358 35.22936)
# 8      Sandusky   POINT (-82.71031 41.45019)
# 9       Vaughan   POINT (-79.50874 43.82140)
# 10        Mason   POINT (-84.30925 39.36032)
# 11      Doswell   POINT (-77.46460 37.86022)

# %%
#Merge the two dataframes
speed_records = speed_cities.merge(speed_records_final, on='City')
speed_records
# Out:
#            City                     geometry  Rank      Speed  \
# 0     Abu Dhabi    POINT (54.37408 24.47715)   1st  149.1 mph
# 1       Jackson   POINT (-74.42928 40.13295)   2nd    128 mph
# 2      Sandusky   POINT (-82.70645 41.45019)   3rd    120 mph
# 3      Sandusky   POINT (-82.70645 41.45019)   7th     93 mph
# 4      Sandusky   POINT (-82.71031 41.45019)   3rd    120 mph
# 5      Sandusky   POINT (-82.71031 41.45019)   7th     93 mph
# 6   Fujiyoshida   POINT (138.83337 35.48122)   4th  111.8 mph
# 7         Salou     POINT (1.14378 41.07702)   4th  111.8 mph
# 8      Valencia  POINT (-118.56128 34.41396)   5th    100 mph
# 9        Kuwana   POINT (136.64967 35.04827)   6th     95 mph
# 10    Charlotte   POINT (-80.84358 35.22936)   6th     95 mph
# 11      Vaughan   POINT (-79.50874 43.82140)   8th     92 mph
# 12        Mason   POINT (-84.30925 39.36032)   9th     91 mph
# 13      Doswell   POINT (-77.46460 37.86022)  10th     90 mph
#
# ...

# %%
#Drop Duplicate Rows
speed_records = speed_records.drop(labels=[3,4], axis=0)
speed_records = speed_records.reset_index(drop=True)
speed_records
# Out:
#            City                     geometry  Rank      Speed  \
# 0     Abu Dhabi    POINT (54.37408 24.47715)   1st  149.1 mph
# 1       Jackson   POINT (-74.42928 40.13295)   2nd    128 mph
# 2      Sandusky   POINT (-82.70645 41.45019)   3rd    120 mph
# 3      Sandusky   POINT (-82.71031 41.45019)   7th     93 mph
# 4   Fujiyoshida   POINT (138.83337 35.48122)   4th  111.8 mph
# 5         Salou     POINT (1.14378 41.07702)   4th  111.8 mph
# 6      Valencia  POINT (-118.56128 34.41396)   5th    100 mph
# 7        Kuwana   POINT (136.64967 35.04827)   6th     95 mph
# 8     Charlotte   POINT (-80.84358 35.22936)   6th     95 mph
# 9       Vaughan   POINT (-79.50874 43.82140)   8th     92 mph
# 10        Mason   POINT (-84.30925 39.36032)   9th     91 mph
# 11      Doswell   POINT (-77.46460 37.86022)  10th     90 mph
#
#                    Roller Coaster              Amusement Park  \
# 0                   Formula Rossa    Ferrari World Abu Dhabi
# ...

# %%
#Create a GeoJSON of the Speed Records Data
speed_records.to_file("geojsons/speed_records.geojson", driver='GeoJSON')

# %% [markdown]
# ## Height Record Holders Scrape & GeoJSON Creation

# %%
#Set URL for Speed Record Scrape
height_record_url = 'https://rcdb.com/rhr.htm?m=1'

height_tables = pd.read_html(height_record_url)

# %%
#Scrape Height Record Table and save as a dataframe.
height_record = height_tables[1]
height_record
# Out:
#    Rank    Height                 Roller Coaster  \
# 0   1st    456 ft                      Kingda Ka
# 1   2nd    420 ft            Top Thrill Dragster
# 2   3rd    415 ft  Superman: Escape from Krypton
# 3   4th  367.3 ft                      Red Force
# 4   5th    325 ft                       Fury 325
# 5   6th  318.3 ft              Steel Dragon 2000
# 6   7th    310 ft               Millennium Force
# 7   8th    306 ft                      Leviathan
# 8   9th    305 ft                Intimidator 305
# 9  10th    287 ft                          Orion
#
#                            Amusement Park (Location)  Opened
# 0  Six Flags Great Adventure (Jackson, New Jersey...     NaN
# 1        Cedar Point (Sandusky, Ohio, United States)     NaN
# 2  Six Flags Magic Mountain (Valencia, California...     NaN
# 3  Ferrari Land (Salou, Tarragona, Catalonia, Spain)     NaN
# 4  Carowinds (Charlotte, North Carolina, United S...     NaN
# ...

# %%
#Drop unwanted Column
height_record = height_record.drop(labels="Opened", axis=1)
height_record
# Out:
#    Rank    Height                 Roller Coaster  \
# 0   1st    456 ft                      Kingda Ka
# 1   2nd    420 ft            Top Thrill Dragster
# 2   3rd    415 ft  Superman: Escape from Krypton
# 3   4th  367.3 ft                      Red Force
# 4   5th    325 ft                       Fury 325
# 5   6th  318.3 ft              Steel Dragon 2000
# 6   7th    310 ft               Millennium Force
# 7   8th    306 ft                      Leviathan
# 8   9th    305 ft                Intimidator 305
# 9  10th    287 ft                          Orion
#
#                            Amusement Park (Location)
# 0  Six Flags Great Adventure (Jackson, New Jersey...
# 1        Cedar Point (Sandusky, Ohio, United States)
# 2  Six Flags Magic Mountain (Valencia, California...
# 3  Ferrari Land (Salou, Tarragona, Catalonia, Spain)
# 4  Carowinds (Charlotte, North Carolina, United S...
# 5            Nagashima Spa Land (Kuwana, Mie, Japan)
# ...

# %%
#Split the Amusement Park (Location) column & then Drop It
height_record[['Amusement Park','Location']] = height_record['Amusement Park (Location)'].str.split('(',expand=True)
height_record = height_record.drop(labels=['Amusement Park (Location)'], axis=1)
height_record
# Out:
#    Rank    Height                 Roller Coaster              Amusement Park  \
# 0   1st    456 ft                      Kingda Ka  Six Flags Great Adventure
# 1   2nd    420 ft            Top Thrill Dragster                Cedar Point
# 2   3rd    415 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3   4th  367.3 ft                      Red Force               Ferrari Land
# 4   5th    325 ft                       Fury 325                  Carowinds
# 5   6th  318.3 ft              Steel Dragon 2000         Nagashima Spa Land
# 6   7th    310 ft               Millennium Force                Cedar Point
# 7   8th    306 ft                      Leviathan        Canada's Wonderland
# 8   9th    305 ft                Intimidator 305             Kings Dominion
# 9  10th    287 ft                          Orion               Kings Island
#
#                                     Location
# 0        Jackson, New Jersey, United States)
# ...

# %%
#Split the Location into City, State, Country, Etc. 
height_record[['City', 'State', 'Country', 'Extra']] = height_record['Location'].str.split(',', expand=True)
height_record
# Out:
#    Rank    Height                 Roller Coaster              Amusement Park  \
# 0   1st    456 ft                      Kingda Ka  Six Flags Great Adventure
# 1   2nd    420 ft            Top Thrill Dragster                Cedar Point
# 2   3rd    415 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3   4th  367.3 ft                      Red Force               Ferrari Land
# 4   5th    325 ft                       Fury 325                  Carowinds
# 5   6th  318.3 ft              Steel Dragon 2000         Nagashima Spa Land
# 6   7th    310 ft               Millennium Force                Cedar Point
# 7   8th    306 ft                      Leviathan        Canada's Wonderland
# 8   9th    305 ft                Intimidator 305             Kings Dominion
# 9  10th    287 ft                          Orion               Kings Island
#
#                                     Location       City            State  \
# ...

# %%
#Drop Location Column
height_record = height_record.drop(labels=['Location'], axis=1)
height_record
# Out:
#    Rank    Height                 Roller Coaster              Amusement Park  \
# 0   1st    456 ft                      Kingda Ka  Six Flags Great Adventure
# 1   2nd    420 ft            Top Thrill Dragster                Cedar Point
# 2   3rd    415 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3   4th  367.3 ft                      Red Force               Ferrari Land
# 4   5th    325 ft                       Fury 325                  Carowinds
# 5   6th  318.3 ft              Steel Dragon 2000         Nagashima Spa Land
# 6   7th    310 ft               Millennium Force                Cedar Point
# 7   8th    306 ft                      Leviathan        Canada's Wonderland
# 8   9th    305 ft                Intimidator 305             Kings Dominion
# 9  10th    287 ft                          Orion               Kings Island
#
#         City            State          Country    Extra
# 0    Jackson       New Jersey   United States)     None
# ...

# %%
#Remove ) from Country
height_record['Country'] = height_record['Country'].str[:-1]
height_record
# Out:
#    Rank    Height                 Roller Coaster              Amusement Park  \
# 0   1st    456 ft                      Kingda Ka  Six Flags Great Adventure
# 1   2nd    420 ft            Top Thrill Dragster                Cedar Point
# 2   3rd    415 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3   4th  367.3 ft                      Red Force               Ferrari Land
# 4   5th    325 ft                       Fury 325                  Carowinds
# 5   6th  318.3 ft              Steel Dragon 2000         Nagashima Spa Land
# 6   7th    310 ft               Millennium Force                Cedar Point
# 7   8th    306 ft                      Leviathan        Canada's Wonderland
# 8   9th    305 ft                Intimidator 305             Kings Dominion
# 9  10th    287 ft                          Orion               Kings Island
#
#         City            State         Country    Extra
# 0    Jackson       New Jersey   United States     None
# ...

# %%
#Fix Country Column Data
height_record["Country"] = height_record["Country"].str.replace("Cataloni","Spain")
height_record
# Out:
#    Rank    Height                 Roller Coaster              Amusement Park  \
# 0   1st    456 ft                      Kingda Ka  Six Flags Great Adventure
# 1   2nd    420 ft            Top Thrill Dragster                Cedar Point
# 2   3rd    415 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3   4th  367.3 ft                      Red Force               Ferrari Land
# 4   5th    325 ft                       Fury 325                  Carowinds
# 5   6th  318.3 ft              Steel Dragon 2000         Nagashima Spa Land
# 6   7th    310 ft               Millennium Force                Cedar Point
# 7   8th    306 ft                      Leviathan        Canada's Wonderland
# 8   9th    305 ft                Intimidator 305             Kings Dominion
# 9  10th    287 ft                          Orion               Kings Island
#
#         City            State         Country    Extra
# 0    Jackson       New Jersey   United States     None
# ...

# %%
#Drop Extra Column and create Final Dataframe
height_records_final = height_record.drop(labels=['Extra'], axis=1)
height_records_final
# Out:
#    Rank    Height                 Roller Coaster              Amusement Park  \
# 0   1st    456 ft                      Kingda Ka  Six Flags Great Adventure
# 1   2nd    420 ft            Top Thrill Dragster                Cedar Point
# 2   3rd    415 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3   4th  367.3 ft                      Red Force               Ferrari Land
# 4   5th    325 ft                       Fury 325                  Carowinds
# 5   6th  318.3 ft              Steel Dragon 2000         Nagashima Spa Land
# 6   7th    310 ft               Millennium Force                Cedar Point
# 7   8th    306 ft                      Leviathan        Canada's Wonderland
# 8   9th    305 ft                Intimidator 305             Kings Dominion
# 9  10th    287 ft                          Orion               Kings Island
#
#         City            State         Country
# 0    Jackson       New Jersey   United States
# ...

# %%
#Read in the Speed_Cities GeoJSON
height_cities = gp.read_file('geojsons/height_cities.geojson')
height_cities
# Out:
#         City                     geometry
# 0    Jackson   POINT (-74.36474 40.11517)
# 1   Sandusky   POINT (-82.70611 41.45045)
# 2   Valencia  POINT (-118.56085 34.41399)
# 3      Salou     POINT (1.14378 41.07689)
# 4  Charlotte   POINT (-80.84290 35.22823)
# 5     Kuwana   POINT (136.64967 35.04686)
# 6   Sandusky   POINT (-82.71572 41.45096)
# 7    Vaughan   POINT (-79.51149 43.82165)
# 8    Doswell   POINT (-77.46391 37.86076)
# 9      Mason   POINT (-84.31011 39.36045)

# %%
#Merge the two dataframes
height_records = height_cities.merge(height_records_final, on='City')
height_records
# Out:
#          City                     geometry  Rank    Height  \
# 0     Jackson   POINT (-74.36474 40.11517)   1st    456 ft
# 1    Sandusky   POINT (-82.70611 41.45045)   2nd    420 ft
# 2    Sandusky   POINT (-82.70611 41.45045)   7th    310 ft
# 3    Sandusky   POINT (-82.71572 41.45096)   2nd    420 ft
# 4    Sandusky   POINT (-82.71572 41.45096)   7th    310 ft
# 5    Valencia  POINT (-118.56085 34.41399)   3rd    415 ft
# 6       Salou     POINT (1.14378 41.07689)   4th  367.3 ft
# 7   Charlotte   POINT (-80.84290 35.22823)   5th    325 ft
# 8      Kuwana   POINT (136.64967 35.04686)   6th  318.3 ft
# 9     Vaughan   POINT (-79.51149 43.82165)   8th    306 ft
# 10    Doswell   POINT (-77.46391 37.86076)   9th    305 ft
# 11      Mason   POINT (-84.31011 39.36045)  10th    287 ft
#
#                    Roller Coaster              Amusement Park  \
# 0                       Kingda Ka  Six Flags Great Adventure
# 1             Top Thrill Dragster                Cedar Point
# ...

# %%
#Drop Duplicate Rows
height_records = height_records.drop(labels=[2,3], axis=0)
height_records = height_records.reset_index(drop=True)
height_records
# Out:
#         City                     geometry  Rank    Height  \
# 0    Jackson   POINT (-74.36474 40.11517)   1st    456 ft
# 1   Sandusky   POINT (-82.70611 41.45045)   2nd    420 ft
# 2   Sandusky   POINT (-82.71572 41.45096)   7th    310 ft
# 3   Valencia  POINT (-118.56085 34.41399)   3rd    415 ft
# 4      Salou     POINT (1.14378 41.07689)   4th  367.3 ft
# 5  Charlotte   POINT (-80.84290 35.22823)   5th    325 ft
# 6     Kuwana   POINT (136.64967 35.04686)   6th  318.3 ft
# 7    Vaughan   POINT (-79.51149 43.82165)   8th    306 ft
# 8    Doswell   POINT (-77.46391 37.86076)   9th    305 ft
# 9      Mason   POINT (-84.31011 39.36045)  10th    287 ft
#
#                   Roller Coaster              Amusement Park            State  \
# 0                      Kingda Ka  Six Flags Great Adventure        New Jersey
# 1            Top Thrill Dragster                Cedar Point              Ohio
# 2               Millennium Force                Cedar Point              Ohio
# ...

# %%
#Create a GeoJSON of the Height Records Data
height_records.to_file("geojsons/height_records.geojson", driver='GeoJSON')

# %% [markdown]
# ## Length Record Holders Scrape & GeoJSON Creation

# %%
#Set URL for Speed Record Scrape
length_record_url = 'https://rcdb.com/rhr.htm?m=2'

length_tables = pd.read_html(length_record_url)

# %%
#Scrape Length Record Table and save as a dataframe.
length_record = length_tables[1]
length_record
# Out:
#     Rank     Length                                     Roller Coaster  \
# 0    1st  8133.2 ft                                  Steel Dragon 2000
# 1      *    7442 ft                                           Ultimate
# 2    2nd    7359 ft                                              Beast
# 3    3rd  6708.7 ft                                           Fujiyama
# 4    4th    6602 ft                                           Fury 325
# 5    5th    6595 ft                                   Millennium Force
# 6    6th  6561.7 ft                                      Formula Rossa
# 7    7th    6442 ft                                             Voyage
# 8    8th    6072 ft                                     Incredicoaster
# 9    9th    5843 ft                                          Desperado
# 10  10th    5740 ft                                    Steel Vengeance
# 11     *          *  Rankings are not assigned to roller coasters t...
#
# ...

# %%
#Drop unwanted Rows
length_record = length_record.drop(labels=[1,11], axis=0)

#Drop unwanted Column
length_record = length_record.drop(labels="Opened", axis=1)

length_record
# Out:
#     Rank     Length     Roller Coaster  \
# 0    1st  8133.2 ft  Steel Dragon 2000
# 2    2nd    7359 ft              Beast
# 3    3rd  6708.7 ft           Fujiyama
# 4    4th    6602 ft           Fury 325
# 5    5th    6595 ft   Millennium Force
# 6    6th  6561.7 ft      Formula Rossa
# 7    7th    6442 ft             Voyage
# 8    8th    6072 ft     Incredicoaster
# 9    9th    5843 ft          Desperado
# 10  10th    5740 ft    Steel Vengeance
#
#                             Amusement Park (Location)
# 0             Nagashima Spa Land (Kuwana, Mie, Japan)
# 2           Kings Island (Mason, Ohio, United States)
# 3     Fuji-Q Highland (Fujiyoshida, Yamanashi, Japan)
# 4   Carowinds (Charlotte, North Carolina, United S...
# 5         Cedar Point (Sandusky, Ohio, United States)
# 6   Ferrari World Abu Dhabi (Abu Dhabi, Abu Dhabi,...
# 7   Holiday World (Santa Claus, Indiana, United St...
# 8   Disney California Adventure Park (Anaheim, Cal...
# ...

# %%
#Split the Amusement Park (Location) column & then Drop It
length_record[['Amusement Park','Location']] = length_record['Amusement Park (Location)'].str.split('(',expand=True)
length_record = length_record.drop(labels=['Amusement Park (Location)'], axis=1)
length_record
# Out:
#     Rank     Length     Roller Coaster                     Amusement Park  \
# 0    1st  8133.2 ft  Steel Dragon 2000                Nagashima Spa Land
# 2    2nd    7359 ft              Beast                      Kings Island
# 3    3rd  6708.7 ft           Fujiyama                   Fuji-Q Highland
# 4    4th    6602 ft           Fury 325                         Carowinds
# 5    5th    6595 ft   Millennium Force                       Cedar Point
# 6    6th  6561.7 ft      Formula Rossa           Ferrari World Abu Dhabi
# 7    7th    6442 ft             Voyage                     Holiday World
# 8    8th    6072 ft     Incredicoaster  Disney California Adventure Park
# 9    9th    5843 ft          Desperado    Buffalo Bill's Resort & Casino
# 10  10th    5740 ft    Steel Vengeance                       Cedar Point
#
#                                        Location
# 0                           Kuwana, Mie, Japan)
# 2                   Mason, Ohio, United States)
# ...

# %%
#Split the Location into City, State, Country, Etc. 
length_record[['City', 'State', 'Country']] = length_record['Location'].str.split(',', expand=True)
length_record
# Out:
#     Rank     Length     Roller Coaster                     Amusement Park  \
# 0    1st  8133.2 ft  Steel Dragon 2000                Nagashima Spa Land
# 2    2nd    7359 ft              Beast                      Kings Island
# 3    3rd  6708.7 ft           Fujiyama                   Fuji-Q Highland
# 4    4th    6602 ft           Fury 325                         Carowinds
# 5    5th    6595 ft   Millennium Force                       Cedar Point
# 6    6th  6561.7 ft      Formula Rossa           Ferrari World Abu Dhabi
# 7    7th    6442 ft             Voyage                     Holiday World
# 8    8th    6072 ft     Incredicoaster  Disney California Adventure Park
# 9    9th    5843 ft          Desperado    Buffalo Bill's Resort & Casino
# 10  10th    5740 ft    Steel Vengeance                       Cedar Point
#
#                                        Location         City            State  \
# 0                           Kuwana, Mie, Japan)       Kuwana              Mie
# ...

# %%
#Drop Location Column
length_record = length_record.drop(labels=['Location'], axis=1)
length_record
# Out:
#     Rank     Length     Roller Coaster                     Amusement Park  \
# 0    1st  8133.2 ft  Steel Dragon 2000                Nagashima Spa Land
# 2    2nd    7359 ft              Beast                      Kings Island
# 3    3rd  6708.7 ft           Fujiyama                   Fuji-Q Highland
# 4    4th    6602 ft           Fury 325                         Carowinds
# 5    5th    6595 ft   Millennium Force                       Cedar Point
# 6    6th  6561.7 ft      Formula Rossa           Ferrari World Abu Dhabi
# 7    7th    6442 ft             Voyage                     Holiday World
# 8    8th    6072 ft     Incredicoaster  Disney California Adventure Park
# 9    9th    5843 ft          Desperado    Buffalo Bill's Resort & Casino
# 10  10th    5740 ft    Steel Vengeance                       Cedar Point
#
#            City            State                 Country
# 0        Kuwana              Mie                  Japan)
# ...

# %%
#Remove ) from Country & Create Final Dataframe
length_record['Country'] = length_record['Country'].str[:-1]
length_record_final = length_record
length_record_final
# Out:
#     Rank     Length     Roller Coaster                     Amusement Park  \
# 0    1st  8133.2 ft  Steel Dragon 2000                Nagashima Spa Land
# 2    2nd    7359 ft              Beast                      Kings Island
# 3    3rd  6708.7 ft           Fujiyama                   Fuji-Q Highland
# 4    4th    6602 ft           Fury 325                         Carowinds
# 5    5th    6595 ft   Millennium Force                       Cedar Point
# 6    6th  6561.7 ft      Formula Rossa           Ferrari World Abu Dhabi
# 7    7th    6442 ft             Voyage                     Holiday World
# 8    8th    6072 ft     Incredicoaster  Disney California Adventure Park
# 9    9th    5843 ft          Desperado    Buffalo Bill's Resort & Casino
# 10  10th    5740 ft    Steel Vengeance                       Cedar Point
#
#            City            State                Country
# 0        Kuwana              Mie                  Japan
# ...

# %%
#Read in the Speed_Cities GeoJSON
length_cities = gp.read_file('geojsons/length_cities.geojson')
length_cities
# Out:
#           City                     geometry
# 0       Kuwana   POINT (136.64864 35.04714)
# 1        Mason   POINT (-84.30994 39.36071)
# 2  Fujiyoshida   POINT (138.83286 35.48192)
# 3    Charlotte   POINT (-80.84427 35.22767)
# 4     Sandusky   POINT (-82.70542 41.44967)
# 5    Abu Dhabi    POINT (54.36859 24.47965)
# 6  Santa Claus   POINT (-86.91404 38.12024)
# 7      Anaheim  POINT (-117.91283 33.83506)
# 8        Primm  POINT (-115.38666 35.61265)
# 9     Sandusky   POINT (-82.71469 41.45045)

# %%
#Merge the two dataframes
length_records = length_cities.merge(length_record_final, on='City')
length_records
# Out:
#            City                     geometry  Rank     Length  \
# 0        Kuwana   POINT (136.64864 35.04714)   1st  8133.2 ft
# 1         Mason   POINT (-84.30994 39.36071)   2nd    7359 ft
# 2   Fujiyoshida   POINT (138.83286 35.48192)   3rd  6708.7 ft
# 3     Charlotte   POINT (-80.84427 35.22767)   4th    6602 ft
# 4      Sandusky   POINT (-82.70542 41.44967)   5th    6595 ft
# 5      Sandusky   POINT (-82.70542 41.44967)  10th    5740 ft
# 6      Sandusky   POINT (-82.71469 41.45045)   5th    6595 ft
# 7      Sandusky   POINT (-82.71469 41.45045)  10th    5740 ft
# 8     Abu Dhabi    POINT (54.36859 24.47965)   6th  6561.7 ft
# 9   Santa Claus   POINT (-86.91404 38.12024)   7th    6442 ft
# 10      Anaheim  POINT (-117.91283 33.83506)   8th    6072 ft
# 11        Primm  POINT (-115.38666 35.61265)   9th    5843 ft
#
#        Roller Coaster                     Amusement Park            State  \
# 0   Steel Dragon 2000                Nagashima Spa Land               Mie
# ...

# %%
#Drop Duplicate Rows
length_records = length_records.drop(labels=[5,6], axis=0)
length_records = length_records.reset_index(drop=True)
length_records
# Out:
#           City                     geometry  Rank     Length  \
# 0       Kuwana   POINT (136.64864 35.04714)   1st  8133.2 ft
# 1        Mason   POINT (-84.30994 39.36071)   2nd    7359 ft
# 2  Fujiyoshida   POINT (138.83286 35.48192)   3rd  6708.7 ft
# 3    Charlotte   POINT (-80.84427 35.22767)   4th    6602 ft
# 4     Sandusky   POINT (-82.70542 41.44967)   5th    6595 ft
# 5     Sandusky   POINT (-82.71469 41.45045)  10th    5740 ft
# 6    Abu Dhabi    POINT (54.36859 24.47965)   6th  6561.7 ft
# 7  Santa Claus   POINT (-86.91404 38.12024)   7th    6442 ft
# 8      Anaheim  POINT (-117.91283 33.83506)   8th    6072 ft
# 9        Primm  POINT (-115.38666 35.61265)   9th    5843 ft
#
#       Roller Coaster                     Amusement Park            State  \
# 0  Steel Dragon 2000                Nagashima Spa Land               Mie
# 1              Beast                      Kings Island              Ohio
# ...

# %%
#Create a GeoJSON of the Length Records Data
length_records.to_file("geojsons/length_records.geojson", driver='GeoJSON')

# %% [markdown]
# ## Drop Record Holders Scrape & GeoJSON Creation

# %%
#Set URL for Drop Record Scrape
drop_record_url = 'https://rcdb.com/rhr.htm?m=3'

drop_tables = pd.read_html(drop_record_url)

# %%
#Scrape Drop Record Table and save as a dataframe.
drop_record = drop_tables[1]
drop_record
# Out:
#    Rank      Drop                        Roller Coaster  \
# 0   1st    418 ft                             Kingda Ka
# 1   2nd    400 ft                   Top Thrill Dragster
# 2   3rd  328.1 ft         Superman: Escape from Krypton
# 3   4th    320 ft                              Fury 325
# 4   5th  306.8 ft                     Steel Dragon 2000
# 5   6th    306 ft                             Leviathan
# 6   7th    300 ft  Millennium ForceIntimidator 305Orion
# 7   8th    269 ft                              Hyperion
# 8   9th  255.9 ft   Coaster Through the CloudsShambhala
# 9  10th    255 ft                          GoliathTitan
#
#                            Amusement Park (Location)  Opened
# 0  Six Flags Great Adventure (Jackson, New Jersey...     NaN
# 1        Cedar Point (Sandusky, Ohio, United States)     NaN
# 2  Six Flags Magic Mountain (Valencia, California...     NaN
# 3  Carowinds (Charlotte, North Carolina, United S...     NaN
# ...

# %%
#Drop unwanted Column
drop_record = drop_record.drop(labels="Opened", axis=1)
drop_record
# Out:
#    Rank      Drop                        Roller Coaster  \
# 0   1st    418 ft                             Kingda Ka
# 1   2nd    400 ft                   Top Thrill Dragster
# 2   3rd  328.1 ft         Superman: Escape from Krypton
# 3   4th    320 ft                              Fury 325
# 4   5th  306.8 ft                     Steel Dragon 2000
# 5   6th    306 ft                             Leviathan
# 6   7th    300 ft  Millennium ForceIntimidator 305Orion
# 7   8th    269 ft                              Hyperion
# 8   9th  255.9 ft   Coaster Through the CloudsShambhala
# 9  10th    255 ft                          GoliathTitan
#
#                            Amusement Park (Location)
# 0  Six Flags Great Adventure (Jackson, New Jersey...
# 1        Cedar Point (Sandusky, Ohio, United States)
# 2  Six Flags Magic Mountain (Valencia, California...
# 3  Carowinds (Charlotte, North Carolina, United S...
# 4            Nagashima Spa Land (Kuwana, Mie, Japan)
# ...

# %%
#Fix Data with Tied Record Holders
drop_fixes = [pd.Series(['7th', '300 ft', 'Millennium Force', 'Cedar Point (Sandusky, Ohio, United States)'], index=drop_record.columns),
                pd.Series(['7th', '300 ft', 'Intimidator 305', 'Kings Dominion (Doswell, Virginia, United States)'], index=drop_record.columns),
                pd.Series(['7th', '300 ft', 'Orion', 'Kings Island (Mason, Ohio, United States)'], index=drop_record.columns),
                pd.Series(['9th', '255.9 ft', 'Coaster Through the Clouds', 'Nanchang Sunac Land (Xinjian, Nanchang, Jiangxi, China)'], index=drop_record.columns),
                pd.Series(['9th', '255.9 ft', 'Shambhala', 'PortAventura Park (Salou, Tarragona, Catalonia, Spain)'], index=drop_record.columns),
                pd.Series(['10th', '255 ft', 'Goliath', 'Six Flags Magic Mountain (Valencia, California, United States)'], index=drop_record.columns),
                pd.Series(['10th', '255 ft', 'Titan', 'Six Flags Over Texas (Arlington, Texas, United States)'], index=drop_record.columns)]
drop_records_fixed = drop_record.append(drop_fixes,ignore_index=True)
drop_records_fixed
# Out:
#     Rank      Drop                        Roller Coaster  \
# 0    1st    418 ft                             Kingda Ka
# 1    2nd    400 ft                   Top Thrill Dragster
# 2    3rd  328.1 ft         Superman: Escape from Krypton
# 3    4th    320 ft                              Fury 325
# 4    5th  306.8 ft                     Steel Dragon 2000
# 5    6th    306 ft                             Leviathan
# 6    7th    300 ft  Millennium ForceIntimidator 305Orion
# 7    8th    269 ft                              Hyperion
# 8    9th  255.9 ft   Coaster Through the CloudsShambhala
# 9   10th    255 ft                          GoliathTitan
# 10   7th    300 ft                      Millennium Force
# 11   7th    300 ft                       Intimidator 305
# 12   7th    300 ft                                 Orion
# 13   9th  255.9 ft            Coaster Through the Clouds
# 14   9th  255.9 ft                             Shambhala
# ...

# %%
#Drop Rows with dirty data
drop_records_clean = drop_records_fixed.drop(labels=[6,8,9], axis=0)
drop_records_clean
# Out:
#     Rank      Drop                 Roller Coaster  \
# 0    1st    418 ft                      Kingda Ka
# 1    2nd    400 ft            Top Thrill Dragster
# 2    3rd  328.1 ft  Superman: Escape from Krypton
# 3    4th    320 ft                       Fury 325
# 4    5th  306.8 ft              Steel Dragon 2000
# 5    6th    306 ft                      Leviathan
# 7    8th    269 ft                       Hyperion
# 10   7th    300 ft               Millennium Force
# 11   7th    300 ft                Intimidator 305
# 12   7th    300 ft                          Orion
# 13   9th  255.9 ft     Coaster Through the Clouds
# 14   9th  255.9 ft                      Shambhala
# 15  10th    255 ft                        Goliath
# 16  10th    255 ft                          Titan
#
#                             Amusement Park (Location)
# 0   Six Flags Great Adventure (Jackson, New Jersey...
# 1         Cedar Point (Sandusky, Ohio, United States)
# ...

# %%
#Split the Amusement Park (Location) column & then Drop It
drop_records_clean[['Amusement Park','Location']] = drop_records_clean['Amusement Park (Location)'].str.split('(',expand=True)
drop_records_clean = drop_records_clean.drop(labels=['Amusement Park (Location)'], axis=1)
drop_records_clean
# Out:
#     Rank      Drop                 Roller Coaster              Amusement Park  \
# 0    1st    418 ft                      Kingda Ka  Six Flags Great Adventure
# 1    2nd    400 ft            Top Thrill Dragster                Cedar Point
# 2    3rd  328.1 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3    4th    320 ft                       Fury 325                  Carowinds
# 4    5th  306.8 ft              Steel Dragon 2000         Nagashima Spa Land
# 5    6th    306 ft                      Leviathan        Canada's Wonderland
# 7    8th    269 ft                       Hyperion               Energylandia
# 10   7th    300 ft               Millennium Force                Cedar Point
# 11   7th    300 ft                Intimidator 305             Kings Dominion
# 12   7th    300 ft                          Orion               Kings Island
# 13   9th  255.9 ft     Coaster Through the Clouds        Nanchang Sunac Land
# ...

# %%
#Split the Location into City, State, Country, Etc. 
drop_records_clean[['City', 'State', 'Country', 'Extra']] = drop_records_clean['Location'].str.split(',', expand=True)
drop_records_clean
# Out:
#     Rank      Drop                 Roller Coaster              Amusement Park  \
# 0    1st    418 ft                      Kingda Ka  Six Flags Great Adventure
# 1    2nd    400 ft            Top Thrill Dragster                Cedar Point
# 2    3rd  328.1 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3    4th    320 ft                       Fury 325                  Carowinds
# 4    5th  306.8 ft              Steel Dragon 2000         Nagashima Spa Land
# 5    6th    306 ft                      Leviathan        Canada's Wonderland
# 7    8th    269 ft                       Hyperion               Energylandia
# 10   7th    300 ft               Millennium Force                Cedar Point
# 11   7th    300 ft                Intimidator 305             Kings Dominion
# 12   7th    300 ft                          Orion               Kings Island
# 13   9th  255.9 ft     Coaster Through the Clouds        Nanchang Sunac Land
# ...

# %%
#Dop Location Column
drop_records_clean = drop_records_clean.drop(labels=['Location'], axis=1)
drop_records_clean
# Out:
#     Rank      Drop                 Roller Coaster              Amusement Park  \
# 0    1st    418 ft                      Kingda Ka  Six Flags Great Adventure
# 1    2nd    400 ft            Top Thrill Dragster                Cedar Point
# 2    3rd  328.1 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3    4th    320 ft                       Fury 325                  Carowinds
# 4    5th  306.8 ft              Steel Dragon 2000         Nagashima Spa Land
# 5    6th    306 ft                      Leviathan        Canada's Wonderland
# 7    8th    269 ft                       Hyperion               Energylandia
# 10   7th    300 ft               Millennium Force                Cedar Point
# 11   7th    300 ft                Intimidator 305             Kings Dominion
# 12   7th    300 ft                          Orion               Kings Island
# 13   9th  255.9 ft     Coaster Through the Clouds        Nanchang Sunac Land
# ...

# %%
#Remove ) from Country 1
drop_records_clean['Country'] = drop_records_clean['Country'].str[:-1]
drop_records_clean
# Out:
#     Rank      Drop                 Roller Coaster              Amusement Park  \
# 0    1st    418 ft                      Kingda Ka  Six Flags Great Adventure
# 1    2nd    400 ft            Top Thrill Dragster                Cedar Point
# 2    3rd  328.1 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3    4th    320 ft                       Fury 325                  Carowinds
# 4    5th  306.8 ft              Steel Dragon 2000         Nagashima Spa Land
# 5    6th    306 ft                      Leviathan        Canada's Wonderland
# 7    8th    269 ft                       Hyperion               Energylandia
# 10   7th    300 ft               Millennium Force                Cedar Point
# 11   7th    300 ft                Intimidator 305             Kings Dominion
# 12   7th    300 ft                          Orion               Kings Island
# 13   9th  255.9 ft     Coaster Through the Clouds        Nanchang Sunac Land
# ...

# %%
#Fix Country Column Data
drop_records_clean["Country"] = drop_records_clean["Country"].str.replace("Cataloni","Spain")
drop_records_clean["Country"] = drop_records_clean["Country"].str.replace("Jiangx","China")
drop_records_clean
# Out:
#     Rank      Drop                 Roller Coaster              Amusement Park  \
# 0    1st    418 ft                      Kingda Ka  Six Flags Great Adventure
# 1    2nd    400 ft            Top Thrill Dragster                Cedar Point
# 2    3rd  328.1 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3    4th    320 ft                       Fury 325                  Carowinds
# 4    5th  306.8 ft              Steel Dragon 2000         Nagashima Spa Land
# 5    6th    306 ft                      Leviathan        Canada's Wonderland
# 7    8th    269 ft                       Hyperion               Energylandia
# 10   7th    300 ft               Millennium Force                Cedar Point
# 11   7th    300 ft                Intimidator 305             Kings Dominion
# 12   7th    300 ft                          Orion               Kings Island
# 13   9th  255.9 ft     Coaster Through the Clouds        Nanchang Sunac Land
# ...

# %%
#Drop Extra Column and create Final Dataframe
drop_records_final = drop_records_clean.drop(labels=['Extra'], axis=1)
drop_records_final
# Out:
#     Rank      Drop                 Roller Coaster              Amusement Park  \
# 0    1st    418 ft                      Kingda Ka  Six Flags Great Adventure
# 1    2nd    400 ft            Top Thrill Dragster                Cedar Point
# 2    3rd  328.1 ft  Superman: Escape from Krypton   Six Flags Magic Mountain
# 3    4th    320 ft                       Fury 325                  Carowinds
# 4    5th  306.8 ft              Steel Dragon 2000         Nagashima Spa Land
# 5    6th    306 ft                      Leviathan        Canada's Wonderland
# 7    8th    269 ft                       Hyperion               Energylandia
# 10   7th    300 ft               Millennium Force                Cedar Point
# 11   7th    300 ft                Intimidator 305             Kings Dominion
# 12   7th    300 ft                          Orion               Kings Island
# 13   9th  255.9 ft     Coaster Through the Clouds        Nanchang Sunac Land
# ...

# %%
#Read in the Speed_Cities GeoJSON
drop_cities = gp.read_file('geojsons/drop_cities.geojson')
drop_cities
# Out:
#          City                     geometry
# 0     Jackson   POINT (-74.36543 40.11589)
# 1    Sandusky   POINT (-82.70782 41.44916)
# 2    Valencia  POINT (-118.56102 34.41413)
# 3   Charlotte   POINT (-80.84427 35.22767)
# 4      Kuwana   POINT (136.64864 35.04714)
# 5     Vaughan   POINT (-79.50874 43.82313)
# 6    Sandusky   POINT (-82.71778 41.44942)
# 7     Doswell   POINT (-77.46460 37.86076)
# 8       Mason   POINT (-84.30977 39.36032)
# 9       Zator    POINT (19.40932 49.99946)
# 10    Xinjian   POINT (115.89478 28.67854)
# 11      Salou     POINT (1.14361 41.07676)
# 12   Valencia  POINT (-118.55536 34.41399)
# 13  Arlington   POINT (-97.10918 32.73617)

# %%
#Merge the two dataframes
drop_records = drop_cities.merge(drop_records_final, on='City')
drop_records
# Out:
#          City                     geometry  Rank      Drop  \
# 0     Jackson   POINT (-74.36543 40.11589)   1st    418 ft
# 1    Sandusky   POINT (-82.70782 41.44916)   2nd    400 ft
# 2    Sandusky   POINT (-82.70782 41.44916)   7th    300 ft
# 3    Sandusky   POINT (-82.71778 41.44942)   2nd    400 ft
# 4    Sandusky   POINT (-82.71778 41.44942)   7th    300 ft
# 5    Valencia  POINT (-118.56102 34.41413)   3rd  328.1 ft
# 6    Valencia  POINT (-118.56102 34.41413)  10th    255 ft
# 7    Valencia  POINT (-118.55536 34.41399)   3rd  328.1 ft
# 8    Valencia  POINT (-118.55536 34.41399)  10th    255 ft
# 9   Charlotte   POINT (-80.84427 35.22767)   4th    320 ft
# 10     Kuwana   POINT (136.64864 35.04714)   5th  306.8 ft
# 11    Vaughan   POINT (-79.50874 43.82313)   6th    306 ft
# 12    Doswell   POINT (-77.46460 37.86076)   7th    300 ft
# 13      Mason   POINT (-84.30977 39.36032)   7th    300 ft
# 14      Zator    POINT (19.40932 49.99946)   8th    269 ft
# ...

# %%
#Drop Duplicate Rows
drop_records = drop_records.drop(labels=[2,3,6,7], axis=0)
drop_records = drop_records.reset_index(drop=True)
drop_records
# Out:
#          City                     geometry  Rank      Drop  \
# 0     Jackson   POINT (-74.36543 40.11589)   1st    418 ft
# 1    Sandusky   POINT (-82.70782 41.44916)   2nd    400 ft
# 2    Sandusky   POINT (-82.71778 41.44942)   7th    300 ft
# 3    Valencia  POINT (-118.56102 34.41413)   3rd  328.1 ft
# 4    Valencia  POINT (-118.55536 34.41399)  10th    255 ft
# 5   Charlotte   POINT (-80.84427 35.22767)   4th    320 ft
# 6      Kuwana   POINT (136.64864 35.04714)   5th  306.8 ft
# 7     Vaughan   POINT (-79.50874 43.82313)   6th    306 ft
# 8     Doswell   POINT (-77.46460 37.86076)   7th    300 ft
# 9       Mason   POINT (-84.30977 39.36032)   7th    300 ft
# 10      Zator    POINT (19.40932 49.99946)   8th    269 ft
# 11    Xinjian   POINT (115.89478 28.67854)   9th  255.9 ft
# 12      Salou     POINT (1.14361 41.07676)   9th  255.9 ft
# 13  Arlington   POINT (-97.10918 32.73617)  10th    255 ft
#
#                    Roller Coaster              Amusement Park  \
# ...

# %%
#Create a GeoJSON of the Speed Records Data
drop_records.to_file("geojsons/drop_records.geojson", driver='GeoJSON')
